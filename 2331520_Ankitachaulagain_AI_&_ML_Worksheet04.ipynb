# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
from PIL import Image

# Define dataset paths (Update this path to match your system)
train_dir = r"/content/DevnagariDataset/DevanagariHandwrittenDigitDataset/Train"
test_dir = r"/content/DevnagariDataset/DevanagariHandwrittenDigitDataset/Test"

# Ensure dataset directories exist
if not os.path.exists(train_dir) or not os.path.exists(test_dir):
    raise FileNotFoundError("Dataset folders not found. Please check the file paths!")

# Define image size
img_height, img_width = 28, 28
# Function to load images and labels using PIL
def load_images_from_folder(folder):
  images = []
  labels = []
  class_names = sorted(os.listdir(folder)) # Sorted class names (digit_0, digit_1, ...)
  class_map = {name: i for i, name in enumerate(class_names)} # Map class names to labels
  for class_name in class_names:
    class_path = os.path.join(folder, class_name)
    label = class_map[class_name]
    for filename in os.listdir(class_path):
      img_path = os.path.join(class_path, filename)
  # Load image using PIL
      img = Image.open(img_path).convert("L") # Convert to grayscale
      img = img.resize((img_width, img_height)) # Resize to (28,28)
      img = np.array(img) / 255.0 # Normalize pixel values to [0,1]
      images.append(img)
      labels.append(label)
  return np.array(images), np.array(labels)
# Load training and testing datasets
x_train, y_train = load_images_from_folder(train_dir)
x_test, y_test = load_images_from_folder(test_dir)
# Reshape images for Keras input
x_train = x_train.reshape(-1, img_height, img_width, 1) # Shape (num_samples, 28, 28, 1)
x_test = x_test.reshape(-1, img_height, img_width, 1)
# One-hot encode labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Print dataset shape
print(f"Training set: {x_train.shape}, Labels: {y_train.shape}")
print(f"Testing set: {x_test.shape}, Labels: {y_test.shape}")
# Visualize some images
plt.figure(figsize=(10, 4))
for i in range(10):
  plt.subplot(2, 5, i + 1)
  plt.imshow(x_train[i].reshape(28, 28), cmap='gray')
  plt.title(f"Label: {np.argmax(y_train[i])}")
  plt.axis("off")
plt.show()
# Apply Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
)
datagen.fit(x_train)
# Out:
# Training set: (17000, 28, 28, 1), Labels: (17000, 10)
# Testing set: (3000, 28, 28, 1), Labels: (3000, 10)

# %%
import zipfile
import os

# Define the path to your ZIP file
zip_path = "/content/drive/MyDrive/AI and Machine Learning (6CS012)/Copy of Copy of devnagari digit.zip"
extract_path = "/content/"

# Unzip the dataset
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction completed!")

# Check extracted files
print("Extracted files:", os.listdir(extract_path))
# Out:
# Extraction completed!
# Extracted files: ['.config', 'DevnagariDataset', 'drive', 'DevanagariHandwrittenDigitDataset', 'sample_data']

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)

# List all folders in the current directory
files_and_folders = os.listdir(current_directory)
print("Files and Folders:", files_and_folders)

# Check if "DevnagariDataset" is in the list
dataset_folder = os.path.join(current_directory, "DevnagariDataset")

if os.path.exists(dataset_folder):
    print("Dataset extracted at:", dataset_folder)
    print("Train Folder Path:", os.path.join(dataset_folder, "train"))
    print("Test Folder Path:", os.path.join(dataset_folder, "test"))
else:
    print("Dataset folder not found! Check your extraction process.")
# Out:
# Current Working Directory: /content
# Files and Folders: ['.config', 'DevnagariDataset', 'drive', 'DevanagariHandwrittenDigitDataset', 'sample_data']
# Dataset extracted at: /content/DevnagariDataset
# Train Folder Path: /content/DevnagariDataset/train
# Test Folder Path: /content/DevnagariDataset/test

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

def build_model():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))  # Flatten the image to 1D vector
    model.add(Dense(64, activation='sigmoid'))  # 1st hidden layer
    model.add(Dense(128, activation='sigmoid'))  # 2nd hidden layer
    model.add(Dense(256, activation='sigmoid'))  # 3rd hidden layer
    model.add(Dense(10, activation='softmax'))  # Output layer with 10 classes (Devnagari digits)

    return model

# Build the model
model = build_model()
model.summary()  # To see the architecture
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
# Define callbacks for early stopping and best model saving
callbacks = [
    ModelCheckpoint(filepath="best_model.keras", save_best_only=True, monitor="val_loss"),
    EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)
]

# Train the model with augmented data
history = model.fit(
    datagen.flow(x_train, y_train, batch_size=128),
    epochs=500,
    validation_data=(x_test, y_test),
    callbacks=callbacks
)
# Out:
# Epoch 1/500
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.2290 - loss: 2.1448 - val_accuracy: 0.7503 - val_loss: 0.9916
# Epoch 2/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.6717 - loss: 1.0332 - val_accuracy: 0.8750 - val_loss: 0.5088
# Epoch 3/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - accuracy: 0.7743 - loss: 0.7020 - val_accuracy: 0.8980 - val_loss: 0.3707
# Epoch 4/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.8154 - loss: 0.5851 - val_accuracy: 0.9203 - val_loss: 0.2989
# Epoch 5/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.8567 - loss: 0.4667 - val_accuracy: 0.9337 - val_loss: 0.2406
# Epoch 6/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.8798 - loss: 0.4004 - val_accuracy: 0.9457 - val_loss: 0.1964
# Epoch 7/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.8936 - loss: 0.3417 - val_accuracy: 0.9553 - val_loss: 0.1713
# Epoch 8/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.9078 - loss: 0.2937 - val_accuracy: 0.9603 - val_loss: 0.1484
# Epoch 9/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.9135 - loss: 0.2646 - val_accuracy: 0.9620 - val_loss: 0.1391
# Epoch 10/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.9178 - loss: 0.2462 - val_accuracy: 0.9657 - val_loss: 0.1256
# Epoch 11/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.9286 - loss: 0.2269 - val_accuracy: 0.9693 - val_loss: 0.1178
# Epoch 12/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.9337 - loss: 0.2112 - val_accuracy: 0.9667 - val_loss: 0.1109
# Epoch 13/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.9378 - loss: 0.2002 - val_accuracy: 0.9740 - val_loss: 0.0997
# Epoch 14/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.9411 - loss: 0.1832 - val_accuracy: 0.9700 - val_loss: 0.1062
# Epoch 15/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.9449 - loss: 0.1768 - val_accuracy: 0.9743 - val_loss: 0.0933
# Epoch 16/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.9465 - loss: 0.1745 - val_accuracy: 0.9700 - val_loss: 0.1035
# Epoch 17/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.9427 - loss: 0.1779 - val_accuracy: 0.9770 - val_loss: 0.0866
# Epoch 18/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.9501 - loss: 0.1565 - val_accuracy: 0.9697 - val_loss: 0.0975
# Epoch 19/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.9507 - loss: 0.1557 - val_accuracy: 0.9740 - val_loss: 0.0893
# Epoch 20/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.9502 - loss: 0.1549 - val_accuracy: 0.9757 - val_loss: 0.0849
# Epoch 21/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.9531 - loss: 0.1475 - val_accuracy: 0.9733 - val_loss: 0.0876
# Epoch 22/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.9556 - loss: 0.1400 - val_accuracy: 0.9740 - val_loss: 0.0846
# Epoch 23/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.9589 - loss: 0.1284 - val_accuracy: 0.9760 - val_loss: 0.0860
# Epoch 24/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.9554 - loss: 0.1362 - val_accuracy: 0.9783 - val_loss: 0.0785
# Epoch 25/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.9562 - loss: 0.1332 - val_accuracy: 0.9793 - val_loss: 0.0772
# Epoch 26/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.9507 - loss: 0.1432 - val_accuracy: 0.9780 - val_loss: 0.0764
# Epoch 27/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.9586 - loss: 0.1301 - val_accuracy: 0.9760 - val_loss: 0.0815
# Epoch 28/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.9609 - loss: 0.1259 - val_accuracy: 0.9823 - val_loss: 0.0690
# Epoch 29/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.9628 - loss: 0.1157 - val_accuracy: 0.9823 - val_loss: 0.0701
# Epoch 30/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.9601 - loss: 0.1246 - val_accuracy: 0.9783 - val_loss: 0.0718
# Epoch 31/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - accuracy: 0.9610 - loss: 0.1218 - val_accuracy: 0.9810 - val_loss: 0.0698
# Epoch 32/500
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.9591 - loss: 0.1193 - val_accuracy: 0.9803 - val_loss: 0.0701

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Test accuracy: {test_acc:.4f}")  # Should be between 90-95%

# Save the trained model in the recommended format
model.save("devnagari_digit_classifier.keras")

# Load the saved model
loaded_model = tf.keras.models.load_model("devnagari_digit_classifier.keras")
# Out:
# 94/94 - 0s - 4ms/step - accuracy: 0.9823 - loss: 0.0690
# Test accuracy: 0.9823

# %%
# Make predictions
predictions = loaded_model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)

# Check the first prediction
print(f"Predicted label for first image: {predicted_labels[0]}")
print(f"True label for first image: {np.argmax(y_test[0])}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Predicted label for first image: 0
# True label for first image: 0

# %%
# Plot Training & Validation Accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="Training Accuracy", color="blue")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy", color="orange")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Training Loss", color="blue")
plt.plot(history.history["val_loss"], label="Validation Loss", color="orange")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()

plt.tight_layout()
plt.show()
